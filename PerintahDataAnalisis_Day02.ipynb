# %% [markdown]
# <a href="https://colab.research.google.com/github/Darren0099/Al-manRaffli/blob/main/PerintahDataAnalisis_Day02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3365e64b-de3c-4a9f-aa43-6f3d117abbef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3365e64b-de3c-4a9f-aa43-6f3d117abbef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('/content/data_karirnex_furniturecsv.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9682 entries, 2025 to 2025
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              9682 non-null   int64
#  1   month             9682 non-null   int64
#  2   day               9682 non-null   int64
#  3   sales_date_std    9682 non-null   object
#  4   order_id          9682 non-null   object
#  5   customer_name     9682 non-null   object
#  6   product_name      9682 non-null   object
#  7   category          9682 non-null   int64
#  8   price             9682 non-null   int64
#  9   quantity          9682 non-null   int64
#  10  discount          9682 non-null   int64
#  11  total             9682 non-null   int64
#  12  shipping_fee      9682 non-null   int64
#  13  total_sales       9682 non-null   object
#  14  status            9682 non-null   object
#  15  shipping_address  9682 non-null   object
# ...

# %%
#Insight 1 — Kategori dengan Revenue Tertinggi
category_sales = df.groupby('category')['total_sales'].sum().sort_values(ascending=False)

print(category_sales)
# Out:
# category
# Kamar Tidur    19466170000
# Ruang Tamu     13845615000
# Dapur          10538790000
# Ruang Makan     5352993500
# Ruang Kerja     2014215000
# Penyimpanan     1812005000
# Name: total_sales, dtype: int64

# %%
#Insight 2 — Kota dengan Penjualan Tertinggi
city_sales = df.groupby('kota')['total_sales'].sum().sort_values(ascending=False)

print(city_sales)
# Out:
# kota
# Jakarta Utara        5787592000
# Jakarta Pusat        5616154000
# Jakarta Barat        5540893000
# Jakarta Selatan      5456220500
# Depok                5380480000
# Bogor                5260821500
# Jakarta Timur        5128275000
# Tangerang Selatan    5064556500
# Tangerang            4918396500
# Bekasi               4876399500
# Name: total_sales, dtype: int64

# %%
#Insight 3 — Produk Paling Laris
top_products = df.groupby('product_name')['quantity'].sum().sort_values(ascending=False).head(10)

print(top_products)
# Out:
# product_name
# Meja Rias         1107
# Lemari Sliding    1091
# Lemari TV         1053
# Lemari Baju       1049
# Rak Buku          1034
# Meja Makan        1032
# Kursi Bar         1031
# Meja              1028
# Lemari Dapur      1022
# Lemari Laci       1019
# Name: quantity, dtype: int64

# %%
#mencari data tunggal
pd.to_datetime(
    df['sales_date_std'],
    unit = 'D',
    origin = '1899-12-30'
)
# Out:
# 0      2025-07-31
# 1      2025-11-03
# 2      2025-10-31
# 3      2025-06-19
# 4      2025-06-19
#           ...
# 9995   2025-05-23
# 9996   2025-11-18
# 9997   2025-04-04
# 9998   2025-06-26
# 9999   2025-04-11
# Name: sales_date_std, Length: 10000, dtype: datetime64[ns]

# %%
#Load Dataset dan Menampilkan df.info()
df = pd.read_csv('/content/data_karirnex_furniture.csv')
df.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4515/2134107305.py in <cell line: 0>()
#       1 #Load Dataset dan Menampilkan df.info()
# ----> 2 df = pd.read_csv('/content/data_karirnex_furniture.csv')
#       3 df.info()
#
# ...

# %%
# cek missing values
print(df.isnull().sum())

# cek duplicate rows
print(df.duplicated().sum())

# jumlah data sebelum cleaning
print("Sebelum:", df.shape)

# hapus missing values
df = df.dropna()

# hapus duplicate rows
df = df.drop_duplicates()

# jumlah data sesudah cleaning
print("Sesudah:", df.shape)
# Out:
# year                0
# month               0
# day                 0
# sales_date_std      0
# order_id            0
# customer_name       0
# product_name        0
# category            0
# price               0
# quantity            0
# total               0
# shipping_fee        0
# total_sales         0
# status              0
# shipping_address    0
# kota                0
# dtype: int64
# 0
# Sebelum: (10000, 16)
# Sesudah: (10000, 16)

# %%
#revenue tier
df['revenue_tier'] = pd.cut(
    df['total_sales'],
    bins=[0, 500000, 2000000, float('inf')],
    labels=['Low', 'Mid', 'High']
)

print(df[['total_sales', 'revenue_tier']].head())
# Out:
#    total_sales revenue_tier
# 0      9560000         High
# 1      2060000         High
# 2      2650000         High
# 3     16550000         High
# 4      9660000         High

# %%
#Groupby Mean Total Sales dan Total Quantity
result = df.groupby(['kota', 'category']).agg({
    'total_sales': 'mean',
    'quantity': 'sum'
}).reset_index()

print(result.sort_values(by='total_sales', ascending=False))
# Out:
#                  kota     category   total_sales  quantity
# 42      Jakarta Utara        Dapur  1.230638e+07       231
# 18      Jakarta Barat        Dapur  1.174734e+07       189
# 30    Jakarta Selatan        Dapur  1.118000e+07       188
# 36      Jakarta Timur        Dapur  1.096802e+07       201
# 6               Bogor        Dapur  1.068305e+07       178
# 24      Jakarta Pusat        Dapur  1.058330e+07       180
# 0              Bekasi        Dapur  1.046391e+07       165
# 48          Tangerang        Dapur  1.031302e+07       174
# 12              Depok        Dapur  9.769444e+06       236
# 54  Tangerang Selatan        Dapur  8.421337e+06       188
# 19      Jakarta Barat  Kamar Tidur  6.628050e+06       660
# 31    Jakarta Selatan  Kamar Tidur  6.476564e+06       665
# 25      Jakarta Pusat  Kamar Tidur  6.461751e+06       697
# 55  Tangerang Selatan  Kamar Tidur  6.383163e+06       610
# 43      Jakarta Utara  Kamar Tidur  6.220743e+06       702
# ...
